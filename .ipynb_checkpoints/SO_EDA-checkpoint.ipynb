# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import pickle
import math
import networkx as nx

# %%
def get_stats(array):
    print("Mean:",np.mean(array))
    print("Percentiles")
    for i in [5,25,50,75,90,99, 99.5, 99.7]:
        print(f"{i} - {round(np.percentile(array, i))}")
    print()

# %%
import re
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
    try:
        cleantext = re.sub(CLEANR, '', raw_html)
    except:
        print(raw_html, type(raw_html))
        input()
    return cleantext

# %%
all_tags = pd.read_xml('./stackoverflow/sqls/Tags.xml')

# %%
all_posts = pd.read_xml('./stackoverflow/sqls/Posts.xml', parser='etree')

# %%
all_comments = pd.read_xml('./stackoverflow/sqls/Comments.xml', parser='etree')

# %%
all_users = pd.read_xml('./stackoverflow/sqls/Users.xml')
all_votes = pd.read_xml('./stackoverflow/sqls/Votes.xml')

# %%
user_data = {}
for row in all_users.itertuples():
    if row[1]==-1: continue
    id_ = int(row[1])
    udict = {'uname': row[4], 'bio': cleanhtml(row[8]) if type(row[8])==str else row[8], 'views': row[9], 'upvotes':row[10], 'downvotes':row[11],
                'questions':[], 'answers':[], 'comments':[]}
    user_data[id_] = udict

# %%
len(user_data)
# Out:
# 37616

# %%
edges = defaultdict(list)
post_data = {}
for row in all_posts.itertuples():
    if row[2] not in [1,2]: continue
    tags = row[13][1:-1].split('><') if row[13] else row[13]
    parent_id = -1 if row[2]==1 else int(row[17])
    pdict = {'type':row[2], 'accepted_answer_id':row[3], 'score':row[5], 'views':row[6], 'text':cleanhtml(row[7]),
            'user_id': row[8], 'title':row[12], 'tags':tags, 'rootid': parent_id,  }
    
    if row[2]==1:
        if not math.isnan(row[8]):
            user_data[int(row[8])]['questions'].append(row[1])
    else: 
        edges[parent_id].append([parent_id, row[1]])
        if not math.isnan(row[8]):
            user_data[int(row[8])]['answers'].append(row[1])
            
    post_data[row[1]] = pdict

# %%
len(post_data), len(edges)
# Out:
# (49998, 14537)

# %%
for row in all_comments.itertuples():
    if row[2] not in post_data: continue
    cid = 'c'+str(row[1])
    
    rootid = post_data[row[2]]['rootid'] if post_data[row[2]]['type']==2 else row[2]
    pdict = {'type':3, 'accepted_answer_id':None, 'score':row[3], 'views':None, 'text':cleanhtml(row[4]),
            'user_id': row[6], 'title':None, 'tags':None, 'rootid': rootid,  }
    post_data[cid] = pdict
    edges[rootid].append([row[2], cid])
    
    if row[6] and not math.isnan(row[6]) and row[6]!=-1:
        user_data[int(row[6])]['comments'].append(cid)

# %%
trees = {}
for i,j in edges.items():
    trees[i] = nx.DiGraph(j)

# %%
len(trees)
# Out:
# 15302

# %%
def get_tree_stats(from_rids):
    tree_answers = []
    tree_comments = []
    tree_view = []
    tree_score = []
    tree_topics = []
    tree_length= []
    topic_freq = defaultdict(int)
    tree_id = []
    for rid, G in trees.items():
        if rid not in from_rids:continue
        acnt=0
        ccnt=0
        for pid in G:
            if post_data[pid]['type']==1:
                tree_view.append(post_data[pid]['views'])
                tree_score.append(post_data[pid]['score'])

                if post_data[pid]['tags']:
#                     print(len(post_data[pid]['tags']))
                    tree_topics.append(len(post_data[pid]['tags']))
                    for t in post_data[pid]['tags']:
                        topic_freq[t]+=1
                else:
                    tree_topics.append(0)
            elif post_data[pid]['type']==2: acnt+=1
            elif post_data[pid]['type']==3: ccnt+=1
        tree_comments.append(ccnt)
        tree_answers.append(acnt)
        tree_length.append(ccnt+acnt)
        tree_id.append(rid)
    
    print("topics")
    get_stats(tree_topics)
    print("top freq")
    get_stats(list(topic_freq.values()))
#     print('questions')
#     get_stats(tree_questions)
    print('answers')
    get_stats(tree_answers)
    get_stats(tree_comments)
    print('length')
    get_stats(tree_length)
    return tree_length, tree_id

# %%
tree_length,tree_id=get_tree_stats(list(trees.keys()))
# Out:
# topics
# Mean: 55.558394160583944
# Percentiles
# 5 - 1
# 25 - 4
# 50 - 12
# 75 - 40
# 90 - 109
# 99 - 635
# 99.5 - 797
# 99.7 - 946
#
# answers
# Mean: 2.257548032936871
# Percentiles
# 5 - 1
# 25 - 1
# 50 - 2
# 75 - 3
# 90 - 5
# 99 - 11
# 99.5 - 13
# 99.7 - 15
#
# Mean: 11.48039471964449
# Percentiles
# 5 - 0
# 25 - 3
# 50 - 7
# 75 - 15
# 90 - 27
# 99 - 68
# 99.5 - 82
# 99.7 - 91
#
# Mean: 13.737942752581361
# Percentiles
# 5 - 1
# 25 - 4
# 50 - 9
# 75 - 17
# 90 - 31
# 99 - 78
# 99.5 - 93
# 99.7 - 105

# %%
sorted(topic_freq.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('united-states', 6742),
#  ('united-kingdom', 1534),
#  ('election', 978),
#  ('european-union', 908),
#  ('russian-federation', 809),
#  ('president', 697),
#  ('international-relations', 677),
#  ('law', 664),
#  ('donald-trump', 642),
#  ('presidential-election', 609),
#  ('brexit', 596),
#  ('economy', 564),
#  ('congress', 546),
#  ('constitution', 527),
#  ('china', 498),
#  ('voting', 473),
#  ('armed-conflict', 464),
#  ('ukraine', 436),
#  ('democracy', 403),
#  ('parliament', 400),
#  ('parties', 395),
#  ('military', 388),
#  ('international-law', 381),
#  ('political-theory', 360),
#  ('senate', 347),
#  ('india', 340),
#  ('government', 320),
#  ('covid-19', 310),
#  ('history', 293),
#  ('international', 283),
#  ('taxes', 270),
#  ('terminology', 262),
#  ('supreme-court', 246),
#  ('united-nations', 238),
#  ('voting-systems', 236),
#  ('public-opinion', 235),
#  ('policy', 231),
#  ('trade', 227),
#  ('israel', 223),
#  ('immigration', 213),
#  ('germany', 210),
#  ('media', 209),
#  ('house-of-representatives', 204),
#  ('impeachment', 196),
#  ('healthcare', 188),
#  ('sanctions', 182),
#  ('ideology', 179),
#  ('terrorism', 175),
#  ('iran', 172),
#  ('nuclear-weapons', 170),
#  ('europe', 168),
#  ('nato', 168),
#  ('turkey', 167),
#  ('legislative-process', 162),
#  ('political-system', 156),
#  ('republican-party', 156),
#  ('democratic-party', 151),
#  ('electoral-college', 147),
#  ('france', 147),
#  ('geopolitics', 145),
#  ('demographics', 145),
#  ('judiciary', 144),
#  ('budget', 144),
#  ('statistics', 139),
#  ('pakistan', 137),
#  ('religion', 134),
#  ('canada', 132),
#  ('senate-rules', 131),
#  ('north-korea', 130),
#  ('us-state-laws', 127),
#  ('syria', 126),
#  ('foreign-policy', 125),
#  ('australia', 124),
#  ('police', 124),
#  ('primaries', 117),
#  ('trump-impeachment', 117),
#  ('communism', 115),
#  ('debt', 113),
#  ('human-rights', 112),
#  ('protests', 111),
#  ('borders', 110),
#  ('education', 109),
#  ('legislation', 109),
#  ('reference-request', 109),
#  ('campaigning', 105),
#  ('comparative-politics', 105),
#  ('crime', 104),
#  ('house-of-commons', 103),
#  ('palestine', 100),
#  ('public-health', 99),
#  ('referendum', 97),
#  ('socialism', 97),
#  ('treaty', 97),
#  ('climate-change', 95),
#  ('northern-ireland', 95),
#  ('executive', 94),
#  ('monarchy', 94),
#  ('middle-east', 94),
#  ('freedom-of-speech', 93),
#  ('joe-biden', 93),
#  ('secession', 92),
#  ('federalism', 90),
#  ('local-government', 88),
#  ('campaign-finance', 87),
#  ('afghanistan', 87),
#  ('guns', 85),
#  ('saudi-arabia', 85),
#  ('western-world', 84),
#  ('corruption', 82),
#  ('government-shutdown', 80),
#  ('civil-rights', 79),
#  ('citizenship', 79),
#  ('prime-minister', 79),
#  ('japan', 77),
#  ('data-sources', 76),
#  ('separation-of-powers', 75),
#  ('racism', 74),
#  ('currency', 72),
#  ('employment', 72),
#  ('drugs', 69),
#  ('wto', 69),
#  ('libertarianism', 68),
#  ('regulation', 68),
#  ('technology', 66),
#  ('illegal-immigration', 66),
#  ('social-media', 66),
#  ('refugees', 66),
#  ('polling', 65),
#  ('vice-president', 65),
#  ('conservatism', 65),
#  ('cabinet', 65),
#  ('vladimir-putin', 64),
#  ('procedure', 63),
#  ('iraq', 62),
#  ('weapons', 62),
#  ('environmental-policy', 60),
#  ('taiwan', 59),
#  ('european-parliament', 59),
#  ('lobbying', 58),
#  ('voter-turnout', 58),
#  ('form-of-government', 56),
#  ('liberalism', 56),
#  ('inequality', 55),
#  ('spain', 55),
#  ('transportation', 54),
#  ('capitalism', 54),
#  ('scotland', 54),
#  ('pardon', 53),
#  ('languages', 53),
#  ('california', 53),
#  ('islam', 53),
#  ('discrimination', 53),
#  ('constitutional-monarchy', 52),
#  ('africa', 52),
#  ('asylum', 52),
#  ('barack-obama', 52),
#  ('islamic-state', 52),
#  ('propaganda', 51),
#  ('conservative-party', 51),
#  ('internet', 50),
#  ('sovereignty', 50),
#  ('republic-of-ireland', 50),
#  ('netherlands', 50),
#  ('rules-of-war', 50),
#  ('succession', 49),
#  ('abortion', 49),
#  ('fbi', 49),
#  ('voting-districts', 48),
#  ('hillary-clinton', 48),
#  ('bernie-sanders', 48),
#  ('romania', 48),
#  ('social-welfare', 47),
#  ('marxism', 47),
#  ('sweden', 47),
#  ('voter-registration', 46),
#  ('soviet-union', 46),
#  ('taliban', 46),
#  ('political-spectrum', 45),
#  ('rhetoric', 45),
#  ('poland', 45),
#  ('election-fraud', 45),
#  ('energy-policy', 45),
#  ('nationalism', 44),
#  ('italy', 44),
#  ('south-korea', 44),
#  ('dictatorship', 44),
#  ('territory', 43),
#  ('rule-of-law', 43),
#  ('democratic-primary', 43),
#  ('debate', 43),
#  ('election-requirements', 42),
#  ('corporations', 42),
#  ('lgbt+', 42),
#  ('gender', 42),
#  ('state-legislatures', 42),
#  ('vaccine', 42),
#  ('nomination', 42),
#  ('affordable-care-act', 42),
#  ('mueller-investigation', 42),
#  ('nuclear-energy', 41),
#  ('proportional-representation', 41),
#  ('veto', 40),
#  ('infrastructure', 40),
#  ('society', 40),
#  ('war-crime', 40),
#  ('executive-order', 40),
#  ('speaker', 40),
#  ('ballot', 39),
#  ('privacy', 39),
#  ('amendment', 39),
#  ('trump-wall', 39),
#  ('hong-kong', 39),
#  ('national-security', 38),
#  ('labour-party', 38),
#  ('catalonia', 38),
#  ('flag', 38),
#  ('statehood', 37),
#  ('venezuela', 36),
#  ('political-leaders', 36),
#  ('contested-election', 36),
#  ('embassy', 35),
#  ('vote-by-mail', 35),
#  ('greece', 35),
#  ('ethics', 35),
#  ('boris-johnson', 35),
#  ('gerrymandering', 34),
#  ('anarchism', 34),
#  ('presidential-term', 34),
#  ('space', 34),
#  ('income', 33),
#  ('political-appointments', 33),
#  ('switzerland', 33),
#  ('symbols', 33),
#  ('foreign-aid', 33),
#  ('classified-information', 33),
#  ('legislature', 33),
#  ('summary-request', 32),
#  ('filibuster', 32),
#  ('identity-document', 32),
#  ('visa', 32),
#  ('social-politics', 32),
#  ('fake-news', 32),
#  ('republic', 31),
#  ('financial-crisis', 31),
#  ('civil-war', 31),
#  ('jcpoa', 31),
#  ('territorial-dispute', 31),
#  ('direct-democracy', 30),
#  ('head-of-state', 30),
#  ('power', 30),
#  ('third-party', 30),
#  ('assassinations', 30),
#  ('kurdistan', 30),
#  ('cuba', 29),
#  ('science', 29),
#  ('nazism', 29),
#  ('political-transitions', 29),
#  ('public-sector-compensation', 29),
#  ('federal-reserve', 29),
#  ('intelligence', 29),
#  ('banking', 29),
#  ('crimea', 29),
#  ('mexico', 29),
#  ('population', 28),
#  ('hungary', 28),
#  ('espionage', 28),
#  ('justice-department', 28),
#  ('funding', 28),
#  ('oil', 28),
#  ('who', 28),
#  ('world-war-ii', 27),
#  ('washington-dc', 27),
#  ('electronic-voting', 26),
#  ('euro', 26),
#  ('coup', 26),
#  ('gas', 26),
#  ('agriculture', 26),
#  ('article-50', 26),
#  ('pensions', 26),
#  ('political-research', 25),
#  ('surveillance', 25),
#  ('subsidies', 25),
#  ('member-of-parliament', 25),
#  ('minorities', 25),
#  ('foreign-interference', 25),
#  ('fascism', 24),
#  ('marriage', 24),
#  ('international-court', 24),
#  ('chemical-weapons', 24),
#  ('denmark', 24),
#  ('kashmir', 24),
#  ('genocide', 24),
#  ('finance', 24),
#  ('property', 23),
#  ('egypt', 23),
#  ('house-rules', 23),
#  ('antisemitism', 23),
#  ('republican-primary', 23),
#  ('inauguration', 23),
#  ('state-of-emergency', 23),
#  ('ireland', 23),
#  ('texas', 23),
#  ('commonwealth', 22),
#  ('specific-legislation', 22),
#  ('donbass', 22),
#  ('ngos', 22),
#  ('slavery', 21),
#  ('second-amendment', 21),
#  ('petition', 21),
#  ('labor-union', 21),
#  ('housing', 21),
#  ('special-prosecutor', 21),
#  ('scandal', 21),
#  ('redistricting', 20),
#  ('basic-income', 20),
#  ('military-law', 20),
#  ('checks-and-balances', 20),
#  ('public-administration', 20),
#  ('indigenous-people', 20),
#  ('prison', 20),
#  ('cold-war', 20),
#  ('peace-treaty', 20),
#  ('political-science', 20),
#  ('freedom-of-movement', 20),
#  ('coalition', 20),
#  ('censorship', 20),
#  ('transparency', 19),
#  ('measurement', 19),
#  ('whistleblowers', 19),
#  ('finland', 19),
#  ('paris-agreement', 19),
#  ('census', 19),
#  ('new-york', 19),
#  ('populism', 19),
#  ('intellectual-property', 19),
#  ('florida', 19),
#  ('central-bank', 18),
#  ('land', 18),
#  ('advertising', 18),
#  ('cia', 18),
#  ('house-of-lords', 18),
#  ('unsc', 18),
#  ('conflict-of-interest', 18),
#  ('philippines', 18),
#  ('theresa-may', 18),
#  ('health-insurance', 18),
#  ('faithless-elector', 17),
#  ('puerto-rico', 17),
#  ('bill-of-rights', 17),
#  ('same-sex-marriage', 17),
#  ('money-supply', 17),
#  ('poverty', 17),
#  ('identity-politics', 17),
#  ('green-party', 17),
#  ('city-planning', 17),
#  ('georgia', 17),
#  ('public-funding', 17),
#  ('indonesia', 17),
#  ('tariffs', 17),
#  ('belarus', 17),
#  ('geneva-convention', 16),
#  ('state-department', 16),
#  ('bangladesh', 16),
#  ('new-zealand', 16),
#  ('citizen-activism', 16),
#  ('authoritarianism', 16),
#  ('hate-speech', 16),
#  ('polarization', 16),
#  ('european-commission', 16),
#  ('civil-service', 15),
#  ('feminism', 15),
#  ('sustainable-development', 15),
#  ('copyright', 15),
#  ('voting-records', 15),
#  ('death-penalty', 15),
#  ('brazil', 15),
#  ('royal-family', 15),
#  ('austria', 15),
#  ('energy-independence', 15),
#  ('international-monetary-fund', 15),
#  ('social-security', 14),
#  ('financing', 14),
#  ('game-theory', 14),
#  ('maritime-law', 14),
#  ('us-states', 14),
#  ('country-neutrality', 14),
#  ('conscription', 14),
#  ('norway', 14),
#  ('schengen-area', 14),
#  ('first-amendment', 14),
#  ('united-arab-emirates', 14),
#  ('public-holidays', 14),
#  ('twenty-fifth-amendment', 14),
#  ('extradition', 14),
#  ('azerbaijan', 14),
#  ('first-past-the-post', 13),
#  ('indicators', 13),
#  ('belgium', 13),
#  ('minimum-wage', 13),
#  ('vatican-city', 13),
#  ('gaza', 13),
#  ('net-neutrality', 13),
#  ('election-security', 13),
#  ('recep-tayyip-erdogan', 13),
#  ('jeremy-corbyn', 13),
#  ('myanmar', 13),
#  ('bureaucracy', 13),
#  ('nord-stream', 13),
#  ('prorogation', 13),
#  ('independent-politicians', 12),
#  ('privatization', 12),
#  ('one-person-one-vote', 12),
#  ('public-safety', 12),
#  ('water', 12),
#  ('single-transferable-vote', 12),
#  ('dnc', 12),
#  ('qatar', 12),
#  ('cdc', 12),
#  ('foreign-direct-investment', 12),
#  ('founding-fathers', 11),
#  ('proliferation', 11),
#  ('somalia', 11),
#  ('south-africa', 11),
#  ('intelligence-service', 11),
#  ('iceland', 11),
#  ('freedom-of-information', 11),
#  ('affirmative-action', 11),
#  ('monuments', 11),
#  ('reparations', 11),
#  ('ranked-choice-voting', 11),
#  ('marine-le-pen', 11),
#  ('postal-service', 11),
#  ('christianity', 11),
#  ('vietnam', 11),
#  ('governor', 11),
#  ('thailand', 11),
#  ('czech-republic', 11),
#  ('administrative-division', 10),
#  ('strategic-voting', 10),
#  ('fourteenth-amendment', 10),
#  ('new-york-city', 10),
#  ('anarcho-capitalism', 10),
#  ('hamas', 10),
#  ('conspiracy-theories', 10),
#  ('freedom-of-religion', 10),
#  ('yemen', 10),
#  ('london', 10),
#  ('scottish-national-party', 10),
#  ('exit-polls', 10),
#  ('whipping', 10),
#  ('george-w-bush', 10),
#  ('revolutions', 10),
#  ('secret-ballot', 10),
#  ('michigan', 10),
#  ('nationalization', 10),
#  ('democratic-unionist-party', 10),
#  ('alexei-navalny', 10),
#  ('totalitarianism', 10),
#  ('globalization', 10),
#  ('international-standards', 10),
#  ('judicial-independence', 10),
#  ('empirical-studies', 10),
#  ('chinese-communist-party', 10),
#  ('twelfth-amendment', 9),
#  ('prostitution', 9),
#  ('libya', 9),
#  ('nsa', 9),
#  ('inflation', 9),
#  ('honors', 9),
#  ('rnc', 9),
#  ('ttip', 9),
#  ('good-friday-agreement', 9),
#  ('war-on-drugs', 9),
#  ('new-jersey', 9),
#  ('local-autonomy', 9),
#  ('lithuania', 9),
#  ('bailout', 9),
#  ('fishing', 9),
#  ('cyber-warfare', 9),
#  ('european-council', 9),
#  ('south-america', 9),
#  ('latin-america', 9),
#  ('caucus', 9),
#  ('capitol-riot-investigation', 9),
#  ('ecology', 8),
#  ('michael-bloomberg', 8),
#  ('na-po-vo-inter-co', 8),
#  ('international-waters', 8),
#  ('cyprus', 8),
#  ('decision-making', 8),
#  ('tibet', 8),
#  ('alaska', 8),
#  ('fundraising', 8),
#  ('alt-right', 8),
#  ('wikileaks', 8),
#  ('african-union', 8),
#  ('kosovo', 8),
#  ('serbia', 8),
#  ('turkish-referendum-2017', 8),
#  ('council-of-europe', 8),
#  ('fisa', 8),
#  ('belt-and-road-initiative', 8),
#  ('bhutan', 8),
#  ('daca', 8),
#  ('party-discipline', 8),
#  ('sports', 8),
#  ('immigration-customs-enforcement', 8),
#  ('westminster', 8),
#  ('pennsylvania', 8),
#  ('attorney-general', 8),
#  ('industrial-policy', 8),
#  ('north-america', 8),
#  ('ethiopia', 8),
#  ('gdp', 8),
#  ('armenia', 8),
#  ('liz-truss', 8),
#  ('planning', 7),
#  ('authority', 7),
#  ('nepal', 7),
#  ('oecd', 7),
#  ('g20', 7),
#  ('social-policy', 7),
#  ('disenfranchisement', 7),
#  ('diplomatic-immunity', 7),
#  ('fact-check-request', 7),
#  ('native-americans', 7),
#  ('panama-papers', 7),
#  ('opec', 7),
#  ('judaism', 7),
#  ('forecasting', 7),
#  ('secret-service', 7),
#  ('angela-merkel', 7),
#  ('alcohol', 7),
#  ('republic-of-georgia', 7),
#  ('antitrust', 7),
#  ('private-military-companies', 7),
#  ('singapore', 7),
#  ('social-class', 7),
#  ('jerusalem', 7),
#  ('gdpr', 7),
#  ('secularism', 7),
#  ('brexit-party', 7),
#  ('echr', 7),
#  ('sri-lanka', 7),
#  ('bicameral', 6),
#  ('sortition', 6),
#  ('zionism', 6),
#  ('nevada', 6),
#  ('fines', 6),
#  ('roberts-rules-of-order', 6),
#  ('macedonia', 6),
#  ('complementary-protection', 6),
#  ('bill-clinton', 6),
#  ('oath-of-office', 6),
#  ('contract-law', 6),
#  ('plurality-voting-system', 6),
#  ('infringement', 6),
#  ('ohio', 6),
#  ('wales', 6),
#  ('gibraltar', 6),
#  ('caucasus', 6),
#  ('expat', 6),
#  ('illinois', 6),
#  ('fcc', 6),
#  ('moldova', 6),
#  ('gender-neutrality', 6),
#  ('vienna-convention', 6),
#  ('public-relations', 6),
#  ('voter-suppression', 6),
#  ('efta', 6),
#  ('retirement', 6),
#  ('subpoena', 6),
#  ('green-new-deal', 6),
#  ('haiti', 6),
#  ('cannabis-legalization', 6),
#  ('autocracy', 6),
#  ('fda', 6),
#  ('kamala-harris', 6),
#  ('estonia', 6),
#  ('regime-change', 6),
#  ('pacifism', 5),
#  ('grassroots', 5),
#  ('alp', 5),
#  ('ukip', 5),
#  ('cession', 5),
#  ('zimbabwe', 5),
#  ('party-operations', 5),
#  ('bosnia-and-herzegovina', 5),
#  ('ceta', 5),
#  ('mike-pence', 5),
#  ('julian-assange', 5),
#  ('antifa', 5),
#  ('national-rifle-association', 5),
#  ('cryptocurrency', 5),
#  ('social-justice', 5),
#  ('yugoslavia', 5),
#  ('insurance', 5),
#  ('spheres-of-influence', 5),
#  ('bahrain', 5),
#  ('emmanuel-macron', 5),
#  ('latvia', 5),
#  ('greenland', 5),
#  ('stimulus', 5),
#  ('ochlocracy', 4),
#  ('fec', 4),
#  ('gmo', 4),
#  ('libertarian-party', 4),
#  ('range-voting', 4),
#  ('hezbollah', 4),
#  ('non-aggression', 4),
#  ('loss-of-supply', 4),
#  ('meritocracy', 4),
#  ('arizona', 4),
#  ('apartheid', 4),
#  ('psychology', 4),
#  ('freedom-of-association', 4),
#  ('icc', 4),
#  ('transhumanism', 4),
#  ('north-carolina', 4),
#  ('prohibition', 4),
#  ('morocco', 4),
#  ('rodrigo-duterte', 4),
#  ('hawaii', 4),
#  ('leninism', 4),
#  ('nobel-peace-prize', 4),
#  ('bulgaria', 4),
#  ('slovakia', 4),
#  ('xi-jinping', 4),
#  ('christian-right', 4),
#  ('nancy-pelosi', 4),
#  ('imperialism', 4),
#  ('portugal', 4),
#  ('elizabeth-warren', 4),
#  ('public-image', 4),
#  ('virginia', 4),
#  ('endorsement', 4),
#  ('lebanon', 4),
#  ('persian-gulf', 4),
#  ('gulf-states', 4),
#  ('hhs', 4),
#  ('no-fly-zone', 4),
#  ('strategic-ambiguity', 4),
#  ('egalitarianism', 3),
#  ('historiography', 3),
#  ('diversity-visa-lottery', 3),
#  ('piracy', 3),
#  ('colombia', 3),
#  ('partition', 3),
#  ('rwanda', 3),
#  ('mongolia', 3),
#  ('pvv', 3),
#  ('somaliland', 3),
#  ('ronald-reagan', 3),
#  ('northern-cyprus', 3),
#  ('richard-nixon', 3),
#  ('steve-bannon', 3),
#  ('watergate', 3),
#  ('male-circumcision', 3),
#  ('democratic-socialism', 3),
#  ('animal-rights', 3),
#  ('seventeenth-amendment', 3),
#  ('eminent-domain', 3),
#  ('peru', 3),
#  ('ecuador', 3),
#  ('uyghurs', 3),
#  ('martial-law', 3),
#  ('guatemala', 3),
#  ('osce', 3),
#  ('securities-and-exchange-commission', 3),
#  ('sudan', 3),
#  ('chile', 3),
#  ('monopoly-on-violence', 3),
#  ('liberal-democrats', 3),
#  ('fact-checking', 3),
#  ('iowa', 3),
#  ('balkans', 3),
#  ('slovenia', 3),
#  ('black-lives-matter', 3),
#  ('cptpp', 3),
#  ('keir-starmer', 3),
#  ('malaysia', 3),
#  ('argentina', 3),
#  ('recount', 3),
#  ('aukus', 3),
#  ('labor-policies', 3),
#  ('direct-action', 2),
#  ('hunting', 2),
#  ('biological-weapons', 2),
#  ('tunisia', 2),
#  ('gambling', 2),
#  ('colorado', 2),
#  ('juche', 2),
#  ('kuwait', 2),
#  ('world-bank', 2),
#  ('syndicalism', 2),
#  ('imran-khan', 2),
#  ('mohammed-bin-salman', 2),
#  ('doklam', 2),
#  ('censure', 2),
#  ('civil-union', 2),
#  ('british-channel-islands', 2),
#  ('pkk', 2),
#  ('radiological-weapons', 2),
#  ('gru', 2),
#  ('protocol', 2),
#  ('eritrea', 2),
#  ('mississippi', 2),
#  ('guyana', 2),
#  ('reservation', 2),
#  ('montenegro', 2),
#  ('human-trafficking', 2),
#  ('algeria', 2),
#  ('whaling', 2),
#  ('justin-trudeau', 2),
#  ('karnataka', 2),
#  ('counterintelligence', 2),
#  ('fourth-amendment', 2),
#  ('vote-trading', 2),
#  ('medicare', 2),
#  ('berlin', 2),
#  ('change-uk', 2),
#  ('mitch-mcconnell', 2),
#  ('wisconsin', 2),
#  ('esm', 2),
#  ('kyrgyzstan', 2),
#  ('new-mexico', 2),
#  ('european-economic-area', 2),
#  ('qanon', 2),
#  ('naftali-bennett', 2),
#  ('national-guard', 2),
#  ('self-determination', 2),
#  ('power-sharing', 2),
#  ('shanghai-cooperation-organisation', 2),
#  ('oregon', 2),
#  ('drones', 2),
#  ('xi-jinping-thought', 2),
#  ('indian-national-congress', 2),
#  ('cartoon', 2),
#  ('twitter', 2),
#  ('bjp', 2),
#  ('state-secrets', 2),
#  ('costa-rica', 2),
#  ('jordan', 1),
#  ('sexual-assault', 1),
#  ('missouri', 1),
#  ('jill-stein', 1),
#  ('gitmo', 1),
#  ('luxembourg', 1),
#  ('clinton-foundation', 1),
#  ('macau', 1),
#  ('theodore-roosevelt', 1),
#  ('malta', 1),
#  ('liberia', 1),
#  ('che-guevara', 1),
#  ('oman', 1),
#  ('vienna-convention-law-treaties', 1),
#  ('hugo-chavez', 1),
#  ('naturalization', 1),
#  ('mountain-states', 1),
#  ('instex', 1),
#  ('noocracy', 1),
#  ('nonpartisan-blanket-primary', 1),
#  ('cordon-sanitaire', 1),
#  ('albania', 1),
#  ('samoa', 1),
#  ('esperanto', 1),
#  ('marshall-islands', 1),
#  ('sierra-leone', 1),
#  ('deportation', 1),
#  ('nigeria', 1),
#  ('palau', 1),
#  ('vermont', 1),
#  ('christian-democrat', 1),
#  ('arctic', 1),
#  ('royal-commission', 1),
#  ('eurozone', 1),
#  ('asean', 1),
#  ('ghana', 1),
#  ('black-power', 1),
#  ('fifteenth-amendment', 1),
#  ('tajikistan', 1),
#  ('croatia', 1),
#  ('libertarian-socialism', 1),
#  ('idaho', 1),
#  ('barbados', 1),
#  ('e-democracy', 1),
#  ('mali', 1),
#  ('agenda-2063', 1),
#  ('rhode-island', 1),
#  ('uganda', 1),
#  ('democratic-republic-of-the-congo', 1),
#  ('transnistria', 1),
#  ('territorial-intergrity', 1),
#  ('jimmy-carter', 1),
#  ('montana', 1),
#  ('solomon-islands', 1),
#  ('title-ix', 1),
#  ('maldives', 1),
#  ('kazakhstan', 1),
#  ('kansas', 1),
#  ('fiction', 1),
#  ('iaea', 1),
#  ('media-relations', 1),
#  ('non-recognition', 1),
#  ('minors', 1),
#  ('european-political-community', 1),
#  ('chess', 1),
#  ('bahamas', 1),
#  ('security-guarantees', 1),
#  ('boris-yeltsin', 1),
#  ('fundamentalism', 1),
#  ('state-owned-enterprise', 1),
#  ('building-code', 1),
#  ('social-contract', 1),
#  ('utopia', 1),
#  ('suriname', 1),
#  ('belize', 1),
#  ('guinea-bissau', 1),
#  ('angola', 1),
#  ('uscis', 1),
#  ('neoliberalism', 1),
#  ('sedition', 1)]

# %%
idxs = np.where(np.array(tree_length)>=31)

# %%
top10_tree_id = np.array(tree_id)[idxs]

# %%
len(top10_tree_id)
# Out:
# 1552

# %%
top10_users=set()
top10_posts=set()
for rid in top10_tree_id:
    for pid in trees[rid]:
        top10_users.add(post_data[pid]['user_id'])
        top10_posts.add(pid)

# %%
len(top10_users), len(top10_posts)
# Out:
# (8826, 79130)

# %%
user_views = []
user_num_questions = []
user_num_answers = []
user_num_comments = []
user_interaction = []
user_topics = []

for uid,udict in user_data.items():
    user_views.append(udict['views'])
    
    user_num_questions.append(len(udict['questions']))
    user_num_answers.append(len(udict['answers']))
    user_num_comments.append(len(udict['comments']))
    user_interaction.append(user_num_questions[-1]+user_num_answers[-1]+user_num_comments[-1])
    
    utopics = defaultdict(int)
    for pid in udict['questions']:
        if post_data[pid]['tags']:
            for t in post_data[pid]['tags']:
                utopics[t]+=2
    for pid in udict['answers']:
        rid = post_data[pid]['rootid']
        if post_data[rid]['tags']:
            for t in post_data[rid]['tags']:
                utopics[t]+=1
    for pid in udict['comments']:
        rid = post_data[pid]['rootid']
        if post_data[rid]['tags']:
            for t in post_data[rid]['tags']:
                utopics[t]+=0.5
    user_topics.append(sum(utopics.values()))

# %%
get_stats(user_interaction)
# Out:
# Mean: 5.711027222458529
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 1
# 90 - 4
# 99 - 85
# 99.5 - 177
# 99.7 - 313

# %%
print("Questions per user")
get_stats(user_num_questions)
# Out:
# Questions per user
# Mean: 0.3885580603998299
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 0
# 90 - 1
# 99 - 5
# 99.5 - 10
# 99.7 - 16

# %%
print("Answers per user")
get_stats(user_num_answers)
# Out:
# Answers per user
# Mean: 0.884543811144194
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 0
# 90 - 1
# 99 - 11
# 99.5 - 25
# 99.7 - 49

# %%
print("Comments per user")
get_stats(user_num_comments)
# Out:
# Comments per user
# Mean: 4.4379253509145045
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 0
# 90 - 2
# 99 - 67
# 99.5 - 139
# 99.7 - 259

# %%
print("Views per user")
get_stats(user_views)
# Out:
# Views per user
# Mean: 11.260740110591238
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 2
# 90 - 7
# 99 - 198
# 99.5 - 393
# 99.7 - 639

# %%
print("Topics per user")
get_stats(user_topics)
# Out:
# Topics per user
# Mean: 11.798383666524883
# Percentiles
# 5 - 0
# 25 - 0
# 50 - 0
# 75 - 2
# 90 - 9
# 99 - 177
# 99.5 - 361
# 99.7 - 595

# %%
def get_user_stats(uid_set, top10_posts):
    user_views = []
    user_num_questions = []
    user_num_answers = []
    user_num_comments = []
    user_interaction = []
    user_topics = []
    user_ids = []

    for uid,udict in user_data.items():
        if uid not in uid_set: continue
        user_views.append(udict['views'])
        user_ids.append(uid)
        qids = [i for i in udict['questions'] if i in top10_posts]
        aids = [i for i in udict['answers'] if i in top10_posts]
        cids = [i for i in udict['comments'] if i in top10_posts]

        user_num_questions.append(len(qids))
        user_num_answers.append(len(aids))
        user_num_comments.append(len(cids))
        user_interaction.append(len(qids)+len(aids)+len(cids))

        utopics = defaultdict(int)
        for pid in qids:
            if post_data[pid]['tags']:
                for t in post_data[pid]['tags']:
                    utopics[t]+=2
        for pid in aids:
            rid = post_data[pid]['rootid']
            if post_data[rid]['tags']:
                for t in post_data[rid]['tags']:
                    utopics[t]+=1
        for pid in cids:
            rid = post_data[pid]['rootid']
            if post_data[rid]['tags']:
                for t in post_data[rid]['tags']:
                    utopics[t]+=0.5
        user_topics.append(sum(utopics.values()))
        
    print("Interactions per user")
    get_stats(user_interaction)
    
    print("Topics per user")
    get_stats(user_topics)
    
    return user_interaction, user_ids

# %%
top10_users - set(user_data.keys())
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...}

# %%
len(top10_users)
# Out:
# 8826

# %%
u_inters, user_ids = get_user_stats(top10_users, top10_posts)
# Out:
# Interactions per user
# Mean: 13.91182953710507
# Percentiles
# 5 - 1
# 25 - 1
# 50 - 2
# 75 - 7
# 90 - 23
# 99 - 223
# 99.5 - 337
# 99.7 - 593
#
# Topics per user
# Mean: 25.917983100661278
# Percentiles
# 5 - 1
# 25 - 2
# 50 - 5
# 75 - 13
# 90 - 42
# 99 - 411
# 99.5 - 651
# 99.7 - 1050

# %%
len(u_inters)
# Out:
# 5444

# %%
idxs = np.where(np.array(u_inters)>=23)
top10_tree_top10_users = np.array(user_ids)[idxs]

# %%
top10_tree_top10_users = set(top10_tree_top10_users)

# %%
len(top10_tree_top10_users)
# Out:
# 552

# %%
chosen_trees = []
for rid in top10_tree_id:
    cnt=0
    for pid in trees[rid]:
        if post_data[pid]['type'] in [2] and post_data[pid]['user_id'] in top10_tree_top10_users:
            cnt+=1
    if cnt>=2:
        chosen_trees.append(rid)

# %%
len(chosen_trees)
# Out:
# 1456

# %%
_,_=get_user_stats(top10_tree_top10_users,top10_posts)
# Out:
# Interactions per user
# Mean: 103.77898550724638
# Percentiles
# 5 - 24
# 25 - 33
# 50 - 49
# 75 - 94
# 90 - 223
# 99 - 907
# 99.5 - 1113
# 99.7 - 1200
#
# Topics per user
# Mean: 189.89402173913044
# Percentiles
# 5 - 40
# 25 - 58
# 50 - 90
# 75 - 176
# 90 - 407
# 99 - 1590
# 99.5 - 1911
# 99.7 - 2159

# %%
_,_=get_tree_stats(chosen_trees)
# Out:
# topics
# Mean: 3.161401098901099
# Percentiles
# 5 - 1
# 25 - 2
# 50 - 3
# 75 - 4
# 90 - 5
# 99 - 5
# 99.5 - 5
# 99.7 - 5
#
# top freq
# Mean: 9.187624750499001
# Percentiles
# 5 - 1
# 25 - 1
# 50 - 3
# 75 - 7
# 90 - 19
# 99 - 79
# 99.5 - 105
# 99.7 - 134
#
# answers
# Mean: 6.638049450549451
# Percentiles
# 5 - 3
# 25 - 4
# 50 - 6
# 75 - 8
# 90 - 11
# 99 - 18
# 99.5 - 20
# 99.7 - 22
#
# Mean: 44.03846153846154
# Percentiles
# 5 - 27
# 25 - 31
# 50 - 37
# 75 - 50
# 90 - 70
# 99 - 126
# 99.5 - 146
# 99.7 - 153
#
# length
# Mean: 50.676510989010985
# Percentiles
# 5 - 31
# 25 - 36
# 50 - 43
# 75 - 57
# 90 - 79
# 99 - 143
# 99.5 - 163
# 99.7 - 169

# %%
chosen_trees
# Out:
# [7,
#  17,
#  135,
#  179,
#  238,
#  256,
#  319,
#  323,
#  327,
#  345,
#  404,
#  429,
#  482,
#  489,
#  537,
#  590,
#  586,
#  607,
#  918,
#  1081,
#  1084,
#  1095,
#  1126,
#  1211,
#  1147,
#  1279,
#  1302,
#  1389,
#  1435,
#  1688,
#  1809,
#  1671,
#  1838,
#  2061,
#  2113,
#  2186,
#  2350,
#  2461,
#  2471,
#  2499,
#  2588,
#  2601,
#  2578,
#  2710,
#  2714,
#  2744,
#  2809,
#  2834,
#  2842,
#  2959,
#  3009,
#  3022,
#  2988,
#  3091,
#  3098,
#  3292,
#  3285,
#  3339,
#  3413,
#  4481,
#  4626,
#  4639,
#  4681,
#  4677,
#  4732,
#  4476,
#  4839,
#  5004,
#  4978,
#  6045,
#  6163,
#  6184,
#  6222,
#  6286,
#  6291,
#  6318,
#  6345,
#  6428,
#  6459,
#  6522,
#  6588,
#  7619,
#  7737,
#  7762,
#  7792,
#  7816,
#  7833,
#  7874,
#  7948,
#  8012,
#  8029,
#  8135,
#  8158,
#  8209,
#  8277,
#  8416,
#  8425,
#  8499,
#  8531,
#  8598,
#  8644,
#  8742,
#  1743,
#  8921,
#  8969,
#  9107,
#  9159,
#  9184,
#  9226,
#  9249,
#  9282,
#  9292,
#  9368,
#  9421,
#  9470,
#  9525,
#  9670,
#  10006,
#  10010,
#  10021,
#  10119,
#  10214,
#  10211,
#  10238,
#  10266,
#  10343,
#  10394,
#  10457,
#  10485,
#  10536,
#  10853,
#  10923,
#  10960,
#  11012,
#  11021,
#  11168,
#  11344,
#  11368,
#  11450,
#  11505,
#  11575,
#  11644,
#  11814,
#  11824,
#  11839,
#  12181,
#  12262,
#  12265,
#  12284,
#  12302,
#  12327,
#  12389,
#  12404,
#  12506,
#  12812,
#  12868,
#  12890,
#  13056,
#  13075,
#  13081,
#  13094,
#  13114,
#  13201,
#  13264,
#  13319,
#  13402,
#  13519,
#  13547,
#  13957,
#  14069,
#  14194,
#  14218,
#  14290,
#  14494,
#  14500,
#  14542,
#  14582,
#  14672,
#  14749,
#  14794,
#  14821,
#  14834,
#  14857,
#  14879,
#  14906,
#  14983,
#  15045,
#  15198,
#  15211,
#  15249,
#  15331,
#  15333,
#  15419,
#  15422,
#  15442,
#  15486,
#  15557,
#  15622,
#  15654,
#  15691,
#  15719,
#  15753,
#  15834,
#  15889,
#  15897,
#  15933,
#  15990,
#  16001,
#  16025,
#  16051,
#  16093,
#  16143,
#  16151,
#  16246,
#  16278,
#  16362,
#  16513,
#  16606,
#  16609,
#  16616,
#  16664,
#  16831,
#  16848,
#  16881,
#  17997,
#  18058,
#  18102,
#  18212,
#  13546,
#  18444,
#  18504,
#  18549,
#  18620,
#  18751,
#  18790,
#  18805,
#  18806,
#  18804,
#  18871,
#  19053,
#  19119,
#  19143,
#  19177,
#  19212,
#  19306,
#  19356,
#  19380,
#  18688,
#  19538,
#  19591,
#  19627,
#  19666,
#  19703,
#  19757,
#  19798,
#  19861,
#  19870,
#  19987,
#  20012,
#  20019,
#  20087,
#  20088,
#  20459,
#  20529,
#  20579,
#  20679,
#  20711,
#  21786,
#  21809,
#  21850,
#  21871,
#  21941,
#  21999,
#  22003,
#  23062,
#  23080,
#  23184,
#  23187,
#  23267,
#  23345,
#  23383,
#  23382,
#  23393,
#  23403,
#  23490,
#  23496,
#  23511,
#  23529,
#  23538,
#  23543,
#  23627,
#  23643,
#  23667,
#  23716,
#  23741,
#  23780,
#  23811,
#  23722,
#  23821,
#  23870,
#  23883,
#  23912,
#  23978,
#  23993,
#  24024,
#  24050,
#  24073,
#  24098,
#  24148,
#  24149,
#  24173,
#  24212,
#  24299,
#  24304,
#  24415,
#  24512,
#  24555,
#  24563,
#  24609,
#  24665,
#  24706,
#  24740,
#  24813,
#  24884,
#  24951,
#  25010,
#  25034,
#  25098,
#  25108,
#  25145,
#  25290,
#  25348,
#  25401,
#  25465,
#  25496,
#  25578,
#  25629,
#  25662,
#  25691,
#  25735,
#  25743,
#  25805,
#  25827,
#  25852,
#  25871,
#  25883,
#  25993,
#  26003,
#  26042,
#  26095,
#  26145,
#  26202,
#  26252,
#  26246,
#  26289,
#  26412,
#  26426,
#  26430,
#  26436,
#  26468,
#  26498,
#  26516,
#  26535,
#  26581,
#  26638,
#  26657,
#  26669,
#  26696,
#  26713,
#  26714,
#  26794,
#  26858,
#  26861,
#  26897,
#  26905,
#  26932,
#  27015,
#  27033,
#  27029,
#  27115,
#  27123,
#  27236,
#  27259,
#  27262,
#  27282,
#  27290,
#  27338,
#  27426,
#  27437,
#  27449,
#  27482,
#  27589,
#  27655,
#  27717,
#  27844,
#  27856,
#  27875,
#  27950,
#  27963,
#  27929,
#  28004,
#  28021,
#  28103,
#  28129,
#  28162,
#  28169,
#  28177,
#  28186,
#  28233,
#  28250,
#  28261,
#  28319,
#  28350,
#  28371,
#  28422,
#  28475,
#  28487,
#  28507,
#  28587,
#  29700,
#  29879,
#  29892,
#  29896,
#  29902,
#  29927,
#  29965,
#  30028,
#  30080,
#  30089,
#  30098,
#  30128,
#  30173,
#  30223,
#  30238,
#  30268,
#  30292,
#  30314,
#  30316,
#  30353,
#  30421,
#  30455,
#  30468,
#  30509,
#  30523,
#  30516,
#  30707,
#  30745,
#  30852,
#  30968,
#  30991,
#  31011,
#  31017,
#  31101,
#  31125,
#  31162,
#  31210,
#  31271,
#  31333,
#  31347,
#  31349,
#  31375,
#  31524,
#  31663,
#  31734,
#  31767,
#  31779,
#  31871,
#  31904,
#  31968,
#  32007,
#  32031,
#  32055,
#  32116,
#  32173,
#  32215,
#  32258,
#  32298,
#  32343,
#  32359,
#  32364,
#  32453,
#  32475,
#  32503,
#  32619,
#  32620,
#  32645,
#  32655,
#  32682,
#  32743,
#  32748,
#  32808,
#  32891,
#  32897,
#  32947,
#  32991,
#  33116,
#  33132,
#  33157,
#  33176,
#  33197,
#  33204,
#  33248,
#  33257,
#  33299,
#  33331,
#  33382,
#  33396,
#  33471,
#  33485,
#  33528,
#  33533,
#  33537,
#  33573,
#  33607,
#  33612,
#  33677,
#  33697,
#  33815,
#  33821,
#  33852,
#  33883,
#  33917,
#  33937,
#  33942,
#  33943,
#  33935,
#  33925,
#  34010,
#  34013,
#  34181,
#  34217,
#  34257,
#  34322,
#  34434,
#  34462,
#  34494,
#  34511,
#  34625,
#  34639,
#  34671,
#  34724,
#  34727,
#  34845,
#  34868,
#  34966,
#  34988,
#  35001,
#  35071,
#  35110,
#  35176,
#  35319,
#  35347,
#  35350,
#  35403,
#  35456,
#  35561,
#  35565,
#  35594,
#  35627,
#  35719,
#  35767,
#  35798,
#  35837,
#  35851,
#  35850,
#  35894,
#  36014,
#  36049,
#  36061,
#  37139,
#  37152,
#  37191,
#  37238,
#  37255,
#  37261,
#  37345,
#  37377,
#  37481,
#  37543,
#  37555,
#  37560,
#  35645,
#  37635,
#  37669,
#  37680,
#  37784,
#  37875,
#  37912,
#  37917,
#  37956,
#  37987,
#  38011,
#  38046,
#  38083,
#  38102,
#  38104,
#  38018,
#  38139,
#  38171,
#  38218,
#  38245,
#  38279,
#  38209,
#  38294,
#  38290,
#  38336,
#  38341,
#  38396,
#  38414,
#  38510,
#  38568,
#  38594,
#  38685,
#  38704,
#  38712,
#  38719,
#  38734,
#  38914,
#  38945,
#  38967,
#  39118,
#  39129,
#  39229,
#  39249,
#  39277,
#  39363,
#  39397,
#  39405,
#  39423,
#  39505,
#  39511,
#  39553,
#  39588,
#  39607,
#  39629,
#  39639,
#  39667,
#  39702,
#  39731,
#  39745,
#  39765,
#  39793,
#  39892,
#  39963,
#  39989,
#  40120,
#  40123,
#  40158,
#  40197,
#  40207,
#  40254,
#  40281,
#  40334,
#  40340,
#  40405,
#  40414,
#  40461,
#  40489,
#  40659,
#  40672,
#  40698,
#  40768,
#  40928,
#  40937,
#  41027,
#  41097,
#  41172,
#  41207,
#  41222,
#  41280,
#  41431,
#  41700,
#  41706,
#  41715,
#  41733,
#  41744,
#  41761,
#  41757,
#  41831,
#  41849,
#  41866,
#  41916,
#  41941,
#  41993,
#  42027,
#  42044,
#  42067,
#  42111,
#  42114,
#  42122,
#  42141,
#  42203,
#  42207,
#  42284,
#  42357,
#  42362,
#  42427,
#  42433,
#  42443,
#  42509,
#  42511,
#  42530,
#  42583,
#  42635,
#  42714,
#  42740,
#  42745,
#  42764,
#  42791,
#  42802,
#  42890,
#  42926,
#  42966,
#  43089,
#  43111,
#  43149,
#  43230,
#  43233,
#  43271,
#  43310,
#  43353,
#  43377,
#  43445,
#  43452,
#  43468,
#  43473,
#  43509,
#  43518,
#  43525,
#  43535,
#  43620,
#  43650,
#  43672,
#  43780,
#  43791,
#  43809,
#  43825,
#  43855,
#  43925,
#  43933,
#  43960,
#  43993,
#  44043,
#  44075,
#  44148,
#  44151,
#  44159,
#  44217,
#  44231,
#  44429,
#  45467,
#  45533,
#  45543,
#  45551,
#  45571,
#  45601,
#  45636,
#  45642,
#  45657,
#  45662,
#  45691,
#  45696,
#  45773,
#  45800,
#  45813,
#  45845,
#  45895,
#  45914,
#  45918,
#  46069,
#  46119,
#  46135,
#  46206,
#  45997,
#  46314,
#  46384,
#  46382,
#  46415,
#  46416,
#  46456,
#  46506,
#  46572,
#  46630,
#  46651,
#  46724,
#  46749,
#  46855,
#  46926,
#  46975,
#  47009,
#  47073,
#  47122,
#  47156,
#  47187,
#  47225,
#  47264,
#  47349,
#  47364,
#  47385,
#  47407,
#  47476,
#  47478,
#  47484,
#  47505,
#  47583,
#  47587,
#  47589,
#  47602,
#  47606,
#  47677,
#  47682,
#  47705,
#  47745,
#  47832,
#  47856,
#  47906,
#  47948,
#  47954,
#  47963,
#  48001,
#  48100,
#  48165,
#  48223,
#  48247,
#  48316,
#  48326,
#  48334,
#  48371,
#  48378,
#  48387,
#  48454,
#  48508,
#  48511,
#  48565,
#  48597,
#  48627,
#  48629,
#  48660,
#  48709,
#  48764,
#  48802,
#  48885,
#  48902,
#  48937,
#  48964,
#  49151,
#  49173,
#  49241,
#  49292,
#  49295,
#  49337,
#  49350,
#  49428,
#  49473,
#  49535,
#  49598,
#  49626,
#  49654,
#  49794,
#  49797,
#  49925,
#  49950,
#  50066,
#  50094,
#  50142,
#  50241,
#  50280,
#  50313,
#  50322,
#  50330,
#  50359,
#  50419,
#  50434,
#  50465,
#  50459,
#  50550,
#  50596,
#  50640,
#  50675,
#  50712,
#  50760,
#  50787,
#  50851,
#  50916,
#  50959,
#  50983,
#  51038,
#  51108,
#  51121,
#  51159,
#  51252,
#  52309,
#  52338,
#  52419,
#  52456,
#  52470,
#  52628,
#  52720,
#  52766,
#  52858,
#  53072,
#  53114,
#  53264,
#  53284,
#  53297,
#  53431,
#  53539,
#  53582,
#  53649,
#  53653,
#  53663,
#  53706,
#  53801,
#  53819,
#  53829,
#  53866,
#  53900,
#  53926,
#  53959,
#  53984,
#  54058,
#  54060,
#  54074,
#  54091,
#  54093,
#  54125,
#  54222,
#  54220,
#  54251,
#  54262,
#  54320,
#  54391,
#  54394,
#  54407,
#  54516,
#  54552,
#  54598,
#  54703,
#  54859,
#  54928,
#  54930,
#  54940,
#  56013,
#  56014,
#  56078,
#  56115,
#  56292,
#  56333,
#  56369,
#  56488,
#  56566,
#  56607,
#  56747,
#  56762,
#  56853,
#  56899,
#  56898,
#  56935,
#  56957,
#  56969,
#  56988,
#  57066,
#  57177,
#  57179,
#  57202,
#  57216,
#  57241,
#  57251,
#  57262,
#  57359,
#  57434,
#  57449,
#  57457,
#  57463,
#  57494,
#  57537,
#  57628,
#  57805,
#  57802,
#  57835,
#  57905,
#  57941,
#  57998,
#  59049,
#  59050,
#  59084,
#  59127,
#  59139,
#  59167,
#  59204,
#  59234,
#  59324,
#  59363,
#  59375,
#  59394,
#  59425,
#  59482,
#  59495,
#  59529,
#  59535,
#  ...]

# %%
pickle.dump([trees, user_data, post_data, top10_tree_top10_users, chosen_trees], open('so_politics.pkl','wb'))

# %%
len(trees), len(top10_tree_top10_users), len(chosen_trees)
# Out:
# (15302, 552, 1456)

# %%
from sklearn.model_selection import train_test_split
train_trees, test_trees = train_test_split(chosen_trees, test_size=0.33, random_state=0)

# %%
_,_=get_tree_stats(train_trees)
